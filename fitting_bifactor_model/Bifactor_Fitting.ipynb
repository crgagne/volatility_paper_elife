# %%
# install R packages 

#install.packages('psych')
#install.packages('GPArotation')
#install.packages('nFactors')
#install.packages('polycor')
#install.packages('lavaan')
#install.packages("parameters")
#install.packages('matlib')

# %%
# load R packages 
options(warn=-1)
library(psych)
library(GPArotation)
library(nFactors)
library(polycor)
library(lavaan)
library("parameters")

# %% [markdown]
# ## Load Datasets

# %% [markdown]
# ### Confirmatory

# %%
Q_items_confirmatory_raw_col_rev_all = t(read.csv('../data/item_level_data_for_bifactor_analysis/Q_items_confirmatory_raw_col_rev.csv'))
Q_items_confirmatory_raw_col_rev_all_df = data.frame(Q_items_confirmatory_raw_col_rev_all)
head(Q_items_confirmatory_raw_col_rev_all_df)
# Out:
#    X1 X2 X3 X4 X5 X6 X7 X8 X9 X10 ... X119 X120 X121 X122 X123 X124 X125 X126
# X0 4  2  3  2  2  3  3  2  2  3   ... 0    1    NA   0    0    1    NA   0
# X1 4  2  4  1  1  1  1  1  1  2   ... 0    1     0   2    0    1     0   1
# X3 3  2  3  1  1  3  2  2  2  1   ... 2    2     2   0    0    0     2   2
# X4 3  3  3  3  1  3  3  2  3  2   ... 1    1     0   0    0    1     0   0
# X6 3  2  2  1  1  2  2  2  2  1   ... 1    1     1   1    0    1     1   1
# X7 4  2  3  2  3  3  2  2  2  3   ... 1    2     0   1    1    1     0   1
#    X127 X128
# X0 0    0
# X1 0    0
# X3 0    0
# X4 0    0
# X6 0    0
# X7 0    1

# %%
Q_items_confirmatory_raw_col_rev_all_df_ordered<-Q_items_confirmatory_raw_col_rev_all_df
Q_items_confirmatory_raw_col_rev_all_df_ordered[,
                                   colnames(Q_items_confirmatory_raw_col_rev_all_df_ordered)] <-lapply(Q_items_confirmatory_raw_col_rev_all_df_ordered[,  colnames(Q_items_confirmatory_raw_col_rev_all_df)], ordered)

# %%
nrow(Q_items_confirmatory_raw_col_rev_all)
# Out:
# [1] 325

# %% [markdown]
# ### Experiment 1

# %%
Q_items_cdm_raw_col_rev_all = t(read.csv('../data/item_level_data_for_bifactor_analysis/Q_items_exp1_raw_col_rev.csv'))
Q_items_cdm_raw_col_rev_all_df = data.frame(Q_items_cdm_raw_col_rev_all)
head(Q_items_cdm_raw_col_rev_all_df)
# Out:
#       X1 X2 X3 X4 X5 X6 X7 X8 X9 X10 ... X119 X120 X121 X122 X123 X124 X125
# cb100 4  2  4  3  3  2  2  3  3  4   ... 1    2    0    2    0    2    0
# cb101 2  1  1  1  1  1  1  1  2  1   ... 0    0    0    0    0    0    0
# cb103 4  4  3  4  3  4  4  3  4  3   ... 3    3    1    3    2    3    0
# cb105 4  3  4  4  3  3  4  3  2  3   ... 3    2    2    1    2    2    0
# cb107 3  3  3  2  3  4  4  3  3  3   ... 3    2    2    2    0    2    1
# cb108 4  4  3  4  3  4  4  3  4  3   ... 3    2    1    3    2    2    1
#       X126 X127 X128
# cb100 2    0    2
# cb101 0    0    0
# cb103 3    3    2
# cb105 1    2    2
# cb107 3    1    2
# cb108 2    2    2

# %%
Q_items_cdm_raw_col_rev_all_df_ordered<-Q_items_cdm_raw_col_rev_all_df
Q_items_cdm_raw_col_rev_all_df_ordered[,
                                   colnames(Q_items_cdm_raw_col_rev_all_df_ordered)] <-lapply(Q_items_cdm_raw_col_rev_all_df_ordered[,  colnames(Q_items_cdm_raw_col_rev_all_df)], ordered)

# %%
nrow(Q_items_cdm_raw_col_rev_all)
# Out:
# [1] 86

# %%
ncol(Q_items_cdm_raw_col_rev_all)
# Out:
# [1] 128

# %% [markdown]
# ### Experiment 2

# %%
Q_items_online_raw_col_rev_all = t(read.csv('../data/item_level_data_for_bifactor_analysis/Q_items_exp2_raw_col_rev.csv'))
Q_items_online_raw_col_rev_all_df = data.frame(Q_items_online_raw_col_rev_all)
head(Q_items_online_raw_col_rev_all_df)
# Out:
#       X1 X2 X3 X4 X5 X6 X7 X8 X9 X10 ... X119 X120 X121 X122 X123 X124 X125
# X3259 2  2  1  1  1  1  2  1  1  1   ... NA   NA   NA   NA   NA   NA   NA
# X3337 3  1  2  2  1  2  1  1  2  2   ... NA   NA   NA   NA   NA   NA   NA
# X3364 2  2  1  4  2  4  2  2  3  1   ... NA   NA   NA   NA   NA   NA   NA
# X3394 4  3  3  3  2  3  3  3  3  3   ... NA   NA   NA   NA   NA   NA   NA
# X3502 4  1  2  2  2  3  3  1  1  2   ... NA   NA   NA   NA   NA   NA   NA
# X3544 3  2  1  2  1  3  2  1  1  1   ... NA   NA   NA   NA   NA   NA   NA
#       X126 X127 X128
# X3259 NA   NA   NA
# X3337 NA   NA   NA
# X3364 NA   NA   NA
# X3394 NA   NA   NA
# X3502 NA   NA   NA
# X3544 NA   NA   NA

# %%
nrow(Q_items_online_raw_col_rev_all)
# Out:
# [1] 147

# %%
ncol(Q_items_online_raw_col_rev_all)
# Out:
# [1] 128

# %% [markdown]
# ### Experiment 1 + Confirmatory

# %%
Q_items_cdm_confirmatory_raw_col_rev_all = t(read.csv('../data/item_level_data_for_bifactor_analysis/Q_items_exp1_confirmatory_raw_col_rev.csv'))
Q_items_cdm_confirmatory_raw_col_rev_all_df = data.frame(Q_items_cdm_confirmatory_raw_col_rev_all)
nrow(Q_items_cdm_confirmatory_raw_col_rev_all)
# Out:
# [1] 411

# %% [markdown]
# ### Experiment 1 + Confirmatory + Experiment 2

# %%
Q_items_cdm_confirmatory_online_raw_col_rev_all = t(read.csv('../data/item_level_data_for_bifactor_analysis/Q_items_exp1_confirmatory_exp2_raw_col_rev.csv'))
Q_items_cdm_confirmatory_online_raw_col_rev_all_df = data.frame(Q_items_cdm_confirmatory_online_raw_col_rev_all)
nrow(Q_items_cdm_confirmatory_online_raw_col_rev_all_df)
# Out:
# [1] 558

# %% [markdown]
# ### Labels

# %%
Q_labels = t(read.csv('../data/item_level_data_for_bifactor_analysis/Q_labels_confirmatory.csv'))
head(Q_labels)
# Out:
#               [,1]            [,2]
# Question      I feel pleasant I feel nervous and restless
# Questionnaire STAI            STAI
# Keep          1               1
# Min           2               1
# Max           4               4
# Rev            1              NA
#               [,3]
# Question      I feel satisfied with myself
# Questionnaire STAI
# Keep          1
# Min           1
# Max           4
# Rev            1
#               [,4]
# Question      I wish I could be as happy as others seem to be
# Questionnaire STAI
# Keep          1
# Min           1
# Max           4
# Rev           NA
#               [,5]                  [,6]
# Question      I feel like a failure I feel rested
# Questionnaire STAI                  STAI
# Keep          1                     1
# Min           1                     1
# Max           3                     4
# Rev           NA                     1
#               [,7]
# Question      I am 'calm, cool, and collected'
# Questionnaire STAI
# ...

# %% [markdown]
# ## Number of dimensions

# %% [markdown]
# ### Experiment 1 - random normal

# %%
C = cor(Q_items_cdm_raw_col_rev_all,use = 'pairwise.complete.obs')
ev <- eigen(C) # get eigenvalues
ap <- parallel(subject=82,var=nrow(C),rep=100,cent=.05)
nS <- nScree(x=ev$values, aparallel=ap$eigen$qevpea)
plotnScree(nS)
# Out:
# Plot with title “Non Graphical Solutions to Scree Test”

# %%
sum(ev$values)
# Out:
# [1] 128

# %%
write.csv(ap$eigen,'parrallel.cdm.csv')

# %%
write.csv(ev$values,'eigen.cdm.csv')

# %% [markdown]
# ### Experiment 1 - resampling and random normal

# %%
options(warn=-1)
ap2<-fa.parallel(Q_items_cdm_raw_col_rev_all_df)
# Out:
# The determinant of the smoothed correlation was zero.
# This means the objective function is not defined.
# Chi square is based upon observed residuals.
# The determinant of the smoothed correlation was zero.
# This means the objective function is not defined for the null model either.
# The Chi square is thus based upon observed correlations.
# In factor.scores, the correlation matrix is singular, an approximation is used
# Parallel analysis suggests that the number of factors =  3  and the number of components =  3
# Plot with title “Parallel Analysis Scree Plots”

# %%
write.csv(ap2$fa.simr,'parrallel.fa.sample.cdm.csv')
write.csv(ap2$fa.sim,'parrallel.fa.sim.cdm.csv')

# %% [markdown]
# ## Exploratory Bifactor Analysis

# %%
options(warn=-1)
results2.cdm <-omega(Q_items_cdm_raw_col_rev_all_df,nfactors = 2,
                poly = TRUE,
           flip = FALSE, 
           rotate='oblimin',
          oblique.scores=False)
# Out:
# In smc, smcs < 0 were set to .0
# In smc, smcs < 0 were set to .0
# In smc, smcs < 0 were set to .0
# The determinant of the smoothed correlation was zero.
# This means the objective function is not defined.
# Chi square is based upon observed residuals.
# The determinant of the smoothed correlation was zero.
# This means the objective function is not defined for the null model either.
# The Chi square is thus based upon observed correlations.
#
# Three factors are required for identification -- general factor loadings set to be equal.
# Proceed with caution.
# Think about redoing the analysis with alternative values of the 'option' setting.
#
# In smc, smcs < 0 were set to .0
# The determinant of the smoothed correlation was zero.
# This means the objective function is not defined.
# Chi square is based upon observed residuals.
# The determinant of the smoothed correlation was zero.
# This means the objective function is not defined for the null model either.
# ...

# %%
results2.cdm
# Out:
# Omega
# Call: omegah(m = m, nfactors = nfactors, fm = fm, key = key, flip = flip,
#     digits = digits, title = title, sl = sl, labels = labels,
#     plot = plot, n.obs = n.obs, rotate = rotate, Phi = Phi, option = option,
#     covar = covar, oblique.scores = ..1)
# Alpha:                 0.96
# G.6:                   0.96
# Omega Hierarchical:    0.63
# Omega H asymptotic:    0.66
# Omega Total            0.96
#
# Schmid Leiman Factor loadings greater than  0.2
#          g   F1*   F2*   h2   u2   p2
# X1    0.35  0.40       0.28 0.72 0.43
# X2    0.38        0.27 0.23 0.77 0.63
# X3    0.35  0.30       0.22 0.78 0.57
# X4    0.34  0.39       0.27 0.73 0.43
# X5    0.37  0.31       0.24 0.76 0.59
# X6    0.27             0.11 0.89 0.65
# X7    0.40  0.29       0.26 0.74 0.62
# X8    0.26             0.11 0.89 0.61
# X9    0.34        0.24 0.18 0.82 0.63
# X10   0.29  0.32       0.19 0.81 0.46
# X11   0.34  0.20       0.18 0.82 0.66
# X12   0.27             0.11 0.89 0.65
# ...

# %% [markdown]
# ### Thresholding Loadings

# %%
SL2.cdm<-data.frame(cbind(t(Q_labels),results2.cdm$schmid$sl))
SL2.cdm$g<-round(as.numeric(as.character(SL2.cdm$g)),2)
SL2.cdm$F1.<-round(as.numeric(as.character(SL2.cdm$F1.)),2)
SL2.cdm$F2.<-round(as.numeric(as.character(SL2.cdm$F2.)),2)

# threshold specific factors 
SL2.cdm$F1.[abs(SL2.cdm$F1.)<0.20]=0
SL2.cdm$F2.[abs(SL2.cdm$F2.)<0.20]=0

# %%
write.csv(SL2.cdm,'./bifactor_exp1_poly_loadings.csv')

# %%
SL2.cdm<-read.csv('./bifactor_exp1_poly_loadings.csv')

# %%
head(SL2.cdm)
# Out:
#   X  Question                                        Questionnaire Keep Min Max
# 1 X1 I feel pleasant                                 STAI          1    2   4
# 2 X2 I feel nervous and restless                     STAI          1    1   4
# 3 X3 I feel satisfied with myself                    STAI          1    1   4
# 4 X4 I wish I could be as happy as others seem to be STAI          1    1   4
# 5 X5 I feel like a failure                           STAI          1    1   3
# 6 X6 I feel rested                                   STAI          1    1   4
#   Rev Subscale   g    F1.  F2.  h2        u2        p2
# 1  1  anxiety    0.35 0.40 0.00 0.2829600 0.7170400 0.4336659
# 2 NA  anxiety    0.38 0.00 0.27 0.2342264 0.7657736 0.6263331
# 3  1  depression 0.35 0.30 0.00 0.2156141 0.7843859 0.5745804
# 4 NA  depression 0.34 0.39 0.00 0.2720600 0.7279400 0.4266223
# 5 NA  depression 0.37 0.31 0.00 0.2394413 0.7605587 0.5865976
# ...

# %% [markdown]
# ### Calculating Factor Scores

# %%
### Factor score function 
#- taken from 'psych packages'

# %%
"factor.scores" <- function(x,f,Phi=NULL,method=c("Thurstone","tenBerge","Anderson","Bartlett","Harman","components"),rho=NULL,impute="none") {
#the normal case is f is the structure matrix and Phi is not specified
#Note that the Grice formulas distinguish between Pattern and Structure matrices
#I need to confirm that I am doing this

    if(length(method) > 1) method <- "tenBerge"   #the default
    if(method=="regression") method <- "Thurstone"
    if(method=="tenberge") method <- "tenBerge"
    if(length(class(f)) > 1) { if(inherits(f[2] ,"irt.fa" )) f <- f$fa  }
    
     if(!is.matrix(f)) {Phi <- f$Phi
     f <- loadings(f)
      if(ncol(f)==1) {method <- "Thurstone"}
      }
     nf <- dim(f)[2]
      if(is.null(Phi)) Phi <- diag(1,nf,nf)
     if(dim(x)[1] == dim(f)[1]) {r <- as.matrix(x)
         square <- TRUE} else { 
          square <- FALSE
         if(!is.null(rho)) {r <- rho } else {
          r <- cor(x,use="pairwise") #find the correlation matrix from the data
      }}
      
      S <- f %*% Phi   #the Structure matrix 
   switch(method,   
    "Thurstone" = { w <- try(solve(r,S),silent=TRUE )  #these are the factor weights (see Grice eq. 5)
     	if(inherits(w,"try-error")) {message("In factor.scores, the correlation matrix is singular, an approximation is used")
               r <- cor.smooth(r)}
        
      w <- try(solve(r,S),silent=TRUE)
      if(inherits(w,"try-error")) {message("I was unable to calculate the factor score weights, factor loadings used instead")
               w <- f}
      colnames(w) <- colnames(f)
      rownames(w) <- rownames(f)
       }, 
      
  "tenBerge" = { #Following Grice equation 8 to estimate scores for oblique solutions (with a correction to the second line where r should r.inv
        L <- f %*% matSqrt(Phi)
        r.5 <- invMatSqrt(r)
       
        r <- cor.smooth(r)
        inv.r <- try(solve(r),silent=TRUE)
        if(inherits(inv.r, as.character("try-error")))  {warning("The tenBerge based scoring could not invert the correlation matrix, regression scores found instead")
                                                      ev <- eigen(r)
      ev$values[ev$values < .Machine$double.eps] <- 100 * .Machine$double.eps
        r <- ev$vectors %*% diag(ev$values) %*% t(ev$vectors)
        diag(r)  <- 1
       w <- solve(r,f)}  else {
        C <- r.5 %*% L %*% invMatSqrt(t(L) %*% inv.r %*% L)    #note that this is the correct formula, per Grice personal communication
        w <- r.5 %*% C %*% matSqrt(Phi)}
        colnames(w) <- colnames(f)
        rownames(w) <- rownames(f)
        },

 
       
    "Harman" = { #Grice equation 10 -- 
     #   m <- t(f)  %*% f  #factor intercorrelations 
     m <- f %*% t(S)  #should be this  (the model matrix)  Revised August 31, 2017
     diag(m) <- 1  #Grice does not say this, but it is necessary to make it work!
       inv.m <- solve(m)
     #  w <- f %*%inv.m  
     w <- inv.m %*% f
       }, 
       
       
        
    "Anderson" =  { #scores for orthogonal factor solution will be orthogonal  Grice Eq 7 and 8
    I <- diag(1,nf,nf)
    h2 <-  diag( f %*% Phi %*% t(f))
    U2 <- 1 - h2
    inv.U2 <- diag(1/U2)
    w <- inv.U2 %*% f %*% invMatSqrt(t(f) %*% inv.U2 %*% r %*% inv.U2 %*% f)
    colnames(w) <- colnames(f)
    rownames(w) <- rownames(f)
    },
    
   "Bartlett" = {    #Grice eq 9  # f should be the pattern, not the structure 
    I <- diag(1,nf,nf)
    h2 <-  diag( f %*% Phi %*% t(f))
    U2 <- 1 - h2
    inv.U2 <- diag(1/U2)
    w <- inv.U2 %*% f %*% (solve(t(f) %*% inv.U2 %*% f))
    colnames(w) <- colnames(f)
    rownames(w) <- rownames(f)
    },
    "none" = {w <- NULL},
    
    "components" = {w <- try(solve(r,f),silent=TRUE )    #basically, just do the regression/Thurstone approach for components
                    w <- f }
    )
    
    
    #now find a few fit statistics
    if(is.null(w)) {results <- list(scores=NULL,weights=NULL)} else {
     R2 <- diag(t(w) %*% S)  #this had been   R2 <- diag(t(w) %*% f)   Corrected Sept 1, 2017
     if(any(R2 > 1) || (prod(!is.nan(R2)) <1) || (prod(R2) < 0) ) {#message("The matrix is probably singular -- Factor score estimate results are likely incorrect")
                      R2[abs(R2) > 1] <- NA
                      R2[R2 <= 0] <- NA
                     }
     #if ((max(R2,na.rm=TRUE) > (1 + .Machine$double.eps)) ) {message("The estimated weights for the factor scores are probably incorrect.  Try a different factor extraction method.")}
      r.scores <- cov2cor(t(w) %*% r %*% w) #what actually is this?
     
    
  if(square) {  #that is, if given the correlation matrix
     class(w) <- NULL
     results <- list(scores=NULL,weights=w)
      results$r.scores <- r.scores 
   	  results$R2 <- R2   #this is the multiple R2 of the scores with the factors
     } else {
         missing <- rowSums(is.na(x))
    if(impute !="none") {
       x <- data.matrix(x)
        miss <- which(is.na(x),arr.ind=TRUE)
        if(impute=="mean") {
       		item.means <- colMeans(x,na.rm=TRUE)   #replace missing values with means
       		x[miss]<- item.means[miss[,2]]} else { 
       		item.med   <- apply(x,2,median,na.rm=TRUE) #replace missing with medians
        	x[miss]<- item.med[miss[,2]]}   #this only works if items is a matrix
     }
      

     if(method !="components") {scores <- x %*% w } else {  #standardize the data before doing the regression if using factors, 
        scores <- x %*% w}       # for components, the data have already been zero centered and, if appropriate, scaled
     results <- list(scores=scores,weights=w)
     results$r.scores <- r.scores
     results$missing <- missing 
   	  results$R2 <- R2   #this is the multiple R2 of the scores with the factors
     }
     }
   
     return(results) }
     #how to treat missing data?  see score.item
         
     
"matSqrt" <- function(x) {
   e <- eigen(x)
    e$values[e$values < 0] <- .Machine$double.eps
   sqrt.ev <- sqrt(e$values)   #need to put in a check here for postive semi definite
   result <- e$vectors %*% diag(sqrt.ev) %*% t(e$vectors)
   result}
   
   
"invMatSqrt" <- function(x) {
   e <- eigen(x)
   if(is.complex(e$values)) {warning("complex eigen values detected by invMatSqrt, results are suspect")
                 result <- x
      } else {
      
       e$values[e$values < .Machine$double.eps] <- 100 * .Machine$double.eps
   inv.sqrt.ev <- 1/sqrt(e$values)   #need to put in a check here for postive semi definite
   result <- e$vectors %*% diag(inv.sqrt.ev) %*% t(e$vectors) }
   result}

# %% [markdown]
# ### Scale items altogether then calculate scores separately using Anderson Rubin

# %%
Q_items_cdm_confirmatory_online_raw_col_rev_all_df_scale = scale(Q_items_cdm_confirmatory_online_raw_col_rev_all_df)

# %%
Qcdm<-Q_items_cdm_confirmatory_online_raw_col_rev_all_df_scale[1:86,]
Qj<-Q_items_cdm_confirmatory_online_raw_col_rev_all_df_scale[87:nrow(Q_items_cdm_confirmatory_raw_col_rev_all_df),]
Qo<-Q_items_cdm_confirmatory_online_raw_col_rev_all_df_scale[(nrow(Q_items_cdm_confirmatory_raw_col_rev_all_df)+1):nrow(Q_items_cdm_confirmatory_online_raw_col_rev_all_df),]

# %%
ncol(Qo)
# Out:
# [1] 128

# %% [markdown]
# #### Calculate Scores (experiment 1)

# %%
L2.cdm = SL2.cdm[,c(9,10,11)]
Lmat2.cdm = as.matrix(L2.cdm)
head(Lmat2.cdm)
# Out:
#      g    F1.  F2.
# [1,] 0.35 0.40 0.00
# [2,] 0.38 0.00 0.27
# [3,] 0.35 0.30 0.00
# [4,] 0.34 0.39 0.00
# [5,] 0.37 0.31 0.00
# [6,] 0.27 0.00 0.00

# %%
fscores<-factor.scores(Qcdm,
                       Lmat2.cdm,method ="Anderson",impute = 'mean')
head(fscores$scores)
fscores2.cdm<-fscores
# Out:
#       g          F1.         F2.
# cb100  0.4071684  2.24456440 -0.52462639
# cb101 -0.7925490 -1.15304925 -1.54151695
# cb103  2.7071633  0.18645340 -0.44353038
# cb105  1.8099598  0.90114914 -2.59575558
# cb107  1.7150098  0.79758924 -0.05834366
# cb108  1.8843248  0.07186552  0.57734723

# %%
write.csv(fscores$scores,'./bifactor_exp1_poly_scores_exp1.csv')

# %% [markdown]
# #### Calculate Scores (experiment 2)

# %%
idx<-(data.frame(t(Q_labels))$Questionnaire=='STAI')|(data.frame(t(Q_labels))$Questionnaire=='MASQ')|(data.frame(t(Q_labels))$Questionnaire=='BDI')
sum(idx)
# Out:
# [1] 80

# %%
fscores<-factor.scores(Qo[,idx],
                       Lmat2.cdm[idx,],method ="Anderson",impute = 'mean')
head(fscores$scores)
# Out:
#       g          F1.        F2.
# X3259 -1.0854300 -0.4074615 -0.33590776
# X3337 -1.2869109  0.6932702 -0.03041481
# X3364 -0.6166396  1.1729276  0.45145577
# X3394  1.3534380  1.3690584 -0.60313228
# X3502 -0.3729998  1.2663704 -1.44786366
# X3544 -0.3083075 -1.0773139 -0.55697031

# %%
write.csv(fscores$scores,'./bifactor_exp1_poly_scores_exp2.csv')

# %% [markdown]
# #### Calculate scores (confirmatory)

# %%
fscores2.j<-factor.scores(Qj[complete.cases(Qj),],
                       Lmat2.cdm,method ="Anderson",impute = 'mean')
head(fscores2.j$scores)
# Out:
#     g           F1.        F2.
# X3   0.09772785 -0.2282442  0.01855106
# X4  -0.32142560 -0.6328603  1.19621388
# X7  -0.05447233  1.6819062 -1.22583162
# X9  -0.26880638 -0.8263085  1.76035292
# X13  1.61461686 -0.5032183  0.29544828
# X14 -1.34566624 -0.5433618 -0.64078436

# %%
write.csv(fscores2.j$scores,'./bifactor_exp1_poly_scores_confirmatory.csv')

# %% [markdown]
# ## Exploratory Bifactor Analysis on Confirmatory Sample

# %%
options(warn=-1)
results2.confirm_explore <-omega(Q_items_confirmatory_raw_col_rev_all_df,nfactors = 2,
                poly = TRUE,
           flip = FALSE, 
           rotate='oblimin',
          oblique.scores=False)
# Out:
# In smc, smcs < 0 were set to .0
# In smc, smcs < 0 were set to .0
# In smc, smcs < 0 were set to .0
# The determinant of the smoothed correlation was zero.
# This means the objective function is not defined.
# Chi square is based upon observed residuals.
# The determinant of the smoothed correlation was zero.
# This means the objective function is not defined for the null model either.
# The Chi square is thus based upon observed correlations.
#
# Three factors are required for identification -- general factor loadings set to be equal.
# Proceed with caution.
# Think about redoing the analysis with alternative values of the 'option' setting.
#
# In smc, smcs < 0 were set to .0
# The determinant of the smoothed correlation was zero.
# This means the objective function is not defined.
# Chi square is based upon observed residuals.
# The determinant of the smoothed correlation was zero.
# This means the objective function is not defined for the null model either.
# ...

# %% [markdown]
# ### Thresholding Loadings

# %%
SL2.confirm_explore<-data.frame(cbind(t(Q_labels),results2.confirm_explore$schmid$sl))
SL2.confirm_explore$g<-round(as.numeric(as.character(SL2.confirm_explore$g)),2)
SL2.confirm_explore$F1.<-round(as.numeric(as.character(SL2.confirm_explore$F1.)),2)
SL2.confirm_explore$F2.<-round(as.numeric(as.character(SL2.confirm_explore$F2.)),2)

# threshold specific factors 
SL2.confirm_explore$F1.[abs(SL2.confirm_explore$F1.)<0.20]=0
SL2.confirm_explore$F2.[abs(SL2.confirm_explore$F2.)<0.20]=0

# %%
write.csv(SL2.confirm_explore,'./bifactor_confirmatory_poly_loadings.csv')

# %% [markdown]
# #### factor congruence

# %%
# non-thresholded
factor.congruence(results2.cdm,results2.confirm_explore)
# Out:
#     g    F1*  F2*  h2
# g   0.96 0.75 0.79 0.92
# F1* 0.82 0.81 0.50 0.82
# F2* 0.68 0.32 0.77 0.60
# h2  0.93 0.79 0.70 0.92

# %% [markdown]
# ## Comparing Calculating Scores on a Subset of Items

# %% [markdown]
# ### Exp1 and Confirmatory Group

# %%
Qcdm<-Q_items_cdm_confirmatory_online_raw_col_rev_all_df_scale[1:86,]
Qj<-Q_items_cdm_confirmatory_online_raw_col_rev_all_df_scale[87:nrow(Q_items_cdm_confirmatory_raw_col_rev_all_df),]
Qo<-Q_items_cdm_confirmatory_online_raw_col_rev_all_df_scale[(nrow(Q_items_cdm_confirmatory_raw_col_rev_all_df)+1):nrow(Q_items_cdm_confirmatory_online_raw_col_rev_all_df),]

# %%
Q<-rbind(Qcdm,Qj)

# %%
idx<-(data.frame(t(Q_labels))$Questionnaire=='STAI')|(data.frame(t(Q_labels))$Questionnaire=='MASQ')|(data.frame(t(Q_labels))$Questionnaire=='CESD')
L_red<-Lmat2.cdm[idx,]

# %%
fscores_red<-factor.scores(Q[,idx],L_red,method ="Anderson",impute = 'mean')
nrow(fscores_red$scores)

fscores_full<-factor.scores(Q,Lmat2.cdm,method ="Anderson",impute = 'mean')
nrow(fscores_red$scores)
# Out:
# [1] 411
# [1] 411

# %%
round(cor(fscores_red$scores,fscores_full$scores),2)
# Out:
#     g     F1.   F2.
# g    0.97  0.02 -0.03
# F1. -0.01  0.97  0.12
# F2.  0.08 -0.10  0.41

# %%
round(cor(fscores_red$scores,fscores_full$scores,method='spearman'),2)
# Out:
#     g    F1.   F2.
# g   0.97  0.05 0.08
# F1. 0.02  0.97 0.13
# F2. 0.07 -0.08 0.43

# %% [markdown]
# ### Confirmatory Group Only

# %%
fscores_red<-factor.scores(Qj[,idx],L_red,method ="Anderson",impute = 'mean')
nrow(fscores_red$scores)

fscores_full<-factor.scores(Qj,Lmat2.cdm,method ="Anderson",impute = 'mean')
nrow(fscores_red$scores)
# Out:
# [1] 325
# [1] 325

# %%
round(cor(fscores_red$scores,fscores_full$scores),2)
# Out:
#     g     F1.   F2.
# g    0.97 -0.01 -0.04
# F1. -0.03  0.97  0.15
# F2.  0.08 -0.09  0.41

# %% [markdown]
# ### Exp 1 Group Only

# %%
fscores_red<-factor.scores(Qcdm[,idx],L_red,method ="Anderson",impute = 'mean')
nrow(fscores_red$scores)

fscores_full<-factor.scores(Qcdm,Lmat2.cdm,method ="Anderson",impute = 'mean')
nrow(fscores_red$scores)
# Out:
# [1] 86
# [1] 86

# %%
round(cor(fscores_red$scores,fscores_full$scores),2)
# Out:
#     g    F1.   F2.
# g   0.98  0.06 0.02
# F1. 0.01  0.98 0.00
# F2. 0.10 -0.11 0.35
